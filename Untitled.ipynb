# %%
import pandas as pd

# Lee el archivo de Excel
df = pd.read_excel('data.xlsx')

# Separa las columnas de entrenamiento y prueba
entrenamiento = df['Data'].tolist()
test = df['Etiqueta'].tolist()

# Verifica que las listas se hayan creado correctamente
print(entrenamiento)
print(test)
# Out:
# ['Central Veterinária', 'Adjoint International', 'Ninguna', 'Mensajero', 'Intersoft', 'Central Azucarera Tempisque S.A. (CATSA)', 'Garcés y Gomez Ingenieros S.A.S', 'TAGOSA', 'Nutrimed Healthcare Private Limited', 'Bufete de Abogado Cubero Martínez', 'Medigray', 'Inteca', 'RPC Company', 'Citibank', 'Teki', 'Grupo Interdisciplinario en Consultoría en Proyectos', 'LCS Abogados', 'SiNEM', 'MSP', 'Education Bureau', 'Rahso de Santa Ana', 'ATEK Medical, A Vention Medical Company', 'Grupo Cachos', 'Redvolution Shopper Marketing', 'Burning River Farm', 'Almacén Fiscal del Este', 'SuperPoker', 'saturnia energía', 'NOTARIOS Y ABOGADOS', 'LSG', 'Bus Soluciones Apple Premium Reseller', 'Alpha Pharma Internacional S.A.', 'Liga Tica de Leyendas/ Liga Costarricense de Deportes Electrónicos', 'Almacenes Artelec', 'FH LEGAL', 'Arnaldo Bonilla & Asociados', 'The Printing Factory', 'Bond Enterprises Ltda', 'Tico Electronics - A G.W. Lisk Company', 'ILANUD', 'Toro Group of Companies. MEng, MLA', 'Musico AG', 'Almacenes Generales Quirós', 'United Motors', 'San Andres', 'Projur', 'Grupo Acuña', 'Pj', 'Prodex®', 'MTSS IT Solutions', '20 Microns Limited', 'Bufete Abellán & Asociados', 'iMAS', 'POPIA', 'Portafolio Inmobiliario', 'Circulo Legal', 'Jiménez & Tanzi', 'QAT Global | Custom Software Development', 'Silicon Valley Commerce', 'Buses Para Todos', 'américa ingeniería y arquitectura s.a.', 'Comercial de Seguros', 'Amherst', 'Spark Clear Aligners UK IE', 'LISA APP | Billetera Electrónica', 'González Carvajal y Asociados', 'Distribuidora RW', 'IDMoney', 'CI Cafeterías', 'Hivos', 'Servinco Industrial', 'AIMI Logística', 'Information Technology Support', 'Tropica Studio', 'Sanipro', 'AgroInnovacr', 'OppFi', 'Fruno', 'Regional Centre for Mapping of Resources for Development (RCMRD)', 'Snap Compliance', 'Transmares Costa Rica', 'Cushman & Wakefield | AB Advisory', 'Hultec Terramix S.A.', 'Corporación Pedregal', 'Prospect Social', 'Igleia Luterana Costarricense', 'Confía Corredores de Seguros', 'Confluent Medical Technologies', 'Raleigh International', 'ATI Capital Solutions', 'Tech Logik', 'Vymisa Corp.', 'DELAGRO', 'MARVIN S TOURS COSTA RICA', 'Maquinaria y Tractores Ltda', 'Popular Valores Puesto de Bolsa', 'HiPay', 'SERVICOOP', 'Austrian Service Abroad', 'Transportes H&H', 'BLP Insurance', 'Grupo Aval rental / Alquileres Valverde', 'ROCCA Development Group', 'BPO OUTSOURCING', 'Amaltea AYA', 'Popular Pensiones', 'Regencia Forestal', 'A.M. Costa Rica and Consultantes Río Colorado S.A.', 'Procore Technologies', 'todo natural s.a.', 'Bufete legal.', 'Corporación Font S.A.', 'Imprenta Nacional', 'Colegio Técnico Profesional CIT', 'Alibot', 'Spoon', 'Coopeingenieros R.L.', 'Intensa - Language Institute', 'PHARMA CONSULTING', 'Producciones Crisol SA', 'NewLaw Solicitors', 'Search', 'Global Ecom Partners', 'FARMAVISION S.A.', 'Grupo Ibérico', 'Caribe Hospitality', 'STRATOS FIDUCIARIA', 'CEO of Troy David Mack', 'JG Consultores', 'GRUPO CELCO COSTA RICA,', 'asesor agrícola en fitosanitarios', 'gsk dach', 'Aspen', 'Costa Rican Humanitarian Foundation', 'rivera law firm, llc', 'Banco Cathay', 'FORTEM DEV SERVICES LTDA', 'BUFETE IGNACIO FERNANDEZ', 'Cadexco', 'Likewize Support', 'Argüello Abogados', 'SaborioLaw', 'Conzultek', 'Cámara Oficial Española de Comercio e Industria en Costa Rica', 'Experian Partner Solutions', 'Artlex', 'Defensoría de los Habitantes de Costa Rica', 'Programa Interdisciplinario Costero - IDESPO', 'Grupo Trisan', 'Voice Up Japan', 'Aliato', 'TreviPay', 'Gorilla Logic', 'Agrocosta S. A.', 'Clínica San Agustín', 'Roberto Artavia Consultoría Internacional', 'Borge y Asociados', 'Unity Corredores de Seguros, S.A.', 'PTS Consulting Services', 'Nutri Med S.A.', 'Connor', 'Colegio de Químicos de Costa Rica', 'INTECO - Instituto de Normas Técnicas de Costa Rica', 'ACAM', 'Grupo CS', 'Superintendencia General de Seguros (SUGESE)', 'Colegio de Contadores Privados de Costa Rica', 'Sumedical Medical Supplies', 'SWAT Consulting Services', 'Financie ...
# ['Wholesale', 'Staffing and Recruiting', 'Farming', 'Broadcast Media', 'Information Technology & Services', 'Food Production', 'Construction', 'Mechanical Or Industrial Engineering', 'Food Production', 'Legal Services', 'Pharmaceuticals', 'Information Technology & Services', 'Staffing and Recruiting', 'Banking', 'Information Technology & Services', 'Consultoría y soporte al negocio', 'Legal Services', 'Informática y servicios digitales', 'Information Technology & Services', 'Education Management', 'Financiero, Banca y Valores', 'Medical Device', 'Retail', 'Marketing & Advertising', 'Restaurants', 'Transportation/Trucking/Railroad', 'Sports', 'Energía (Petróleo, Gas y Carbón) y Minería', 'Retail', 'Public Relations and Communications', 'Computer Hardware', 'Químico y farmacéutico, biotecnología', 'Computer Games', 'Retail', 'Law Practice', 'Law Practice', 'Marketing & Advertising', 'Information Technology and Services', 'Electrical & Electronic Manufacturing', 'Government Relations', 'Financiero, Banca y Valores', 'Computer Software', 'Logistics & Supply Chain', 'Automotive', 'Financiero, Banca y Valores', 'Legal Services', 'Financial Services', 'Artes y entretenimiento', 'Construction', 'Government Relations', 'Chemicals', 'Legal Services', 'Information Technology & Services', 'Information Technology & Services', 'Real Estate', 'Law Practice', 'Business Supplies and Equipment', 'Information Technology & Services', 'Retail', 'Transportation/Trucking/Railroad', 'Construction', 'Insurance', 'Financial Services', 'Medical Device', 'Financial Services', 'Management Consulting', 'Transporte (aéreo, marítimo y terrestre) y logística.', 'Program Development', 'Food & Beverages', 'Non-profit Organization Management', 'Mechanical Or Industrial Engineering', 'Transportation/Trucking/Railroad', 'Computer Software', 'Furniture', 'Chemicals', 'Farming', 'Financial Services', 'Computer Software', 'Fundaciones y ONG', 'Information Technology & Services', 'International Trade & Development', 'Real Estate', 'Construction', 'Construction', 'Consultoría y soporte al negocio', 'Fundaciones y ONG', 'Insurance', 'Medical Device', 'Leisure, Travel & Tourism', 'Financial Services', 'Information Technology & Services', 'Food Production', 'Farming', 'Turismo, restauración y hotelería.', 'Construction', 'Banking', 'Computer Software', 'Banking', 'Transporte (aéreo, marítimo y terrestre) y logística', 'Transporte (aéreo, marítimo y terrestre) y logística', 'Insurance', 'Construction', 'Real Estate', 'Outsourcing/Offshoring', 'Químico y farmacéutico, biotecnología', 'Banking', 'Pesca y productos agrícolas/agroindustria.', 'Online Media', 'Computer Software', 'Químico y farmacéutico, biotecnología', 'Legal Services', 'Business Supplies & Equipment', 'Publishing', 'Education', 'Information Technology & Services', 'Financial Services', 'Construction', 'Education Management', 'Pharmaceuticals', 'Artes y entretenimiento', 'Legal Services', 'Informática y servicios digitales', 'Retail', 'Pharmaceuticals', 'Turismo, restauración y hotelería', 'Hospitality', 'Financial Services', 'Financiero, Banca y Valores', 'Public Relations & Communications', 'Financiero, Banca y Valores.', 'Pesca y productos agrícolas/agroindustria', 'Químico y farmacéutico, biotecnología', 'Hospital & Health Care', 'Fundaciones y ONG', 'Legal Services', 'Banking', 'Management Consulting', 'Law Practice', 'Food & Beverages', 'Information Technology & Services', 'Legal Services', 'Legal Services', 'Information Technology & Services', 'International Trade and Development', 'Information Services', 'Law Practice', 'Legal Services', 'Infraestructuras, ingeniería y construcción', 'Biotechnology', 'Servicios Digitales y software', 'Human Resources', 'Financial Services', 'Computer Software', 'Farming', 'Hospital & Health Care', 'Management Consulting', 'Research', 'Insurance', 'Information Technology and Services', 'Pharmaceuticals', 'Management Consulting', 'Government Administration', 'Consumer Se ...

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
import numpy as np
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Lee el archivo de Excel con dos columnas (texto y etiqueta)
df = pd.read_excel('Data.xlsx')

# Separa las columnas de datos y etiquetas
datos = df['Data'].tolist()
etiquetas = df['Etiqueta'].tolist()

# Preprocesamiento de datos
stop_words = set(stopwords.words('english'))
datos_procesados = []
lemmatizer = WordNetLemmatizer()
for texto in datos:
    if isinstance(texto, (int, np.integer, float, np.floating)):
        texto = str(texto)
    tokens = word_tokenize(texto.lower())
    tokens_filtrados = [token for token in tokens if token not in stop_words]
    tokens_lemmatized = [lemmatizer.lemmatize(token) for token in tokens_filtrados]
    datos_procesados.append(' '.join(tokens_lemmatized))

# Crea una nueva columna para los datos preprocesados
df['Columna_de_datos_procesados'] = datos_procesados

# Verifica que los datos se hayan procesado correctamente
print(df.head())
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                     Data                           Etiqueta  \
# 0    Central Veterinária                          Wholesale
# 1  Adjoint International            Staffing and Recruiting
# 2                Ninguna                            Farming
# 3              Mensajero                    Broadcast Media
# 4              Intersoft  Information Technology & Services
#
#   Columna_de_datos_procesados
# 0         central veterinária
# 1       adjoint international
# 2                     ninguna
# 3                   mensajero
# 4                   intersoft

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer

nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Lee el archivo de Excel con dos columnas (texto y etiqueta)
df = pd.read_excel('Data.xlsx')

# Separa las columnas de datos y etiquetas
datos = df['Data'].tolist()
etiquetas = df['Etiqueta'].tolist()

# Preprocesamiento de datos
stop_words = set(stopwords.words('english'))
datos_procesados = []
lemmatizer = WordNetLemmatizer()
for texto in datos:
    if isinstance(texto, (int, np.integer, float, np.floating)):
        texto = str(texto)
    tokens = word_tokenize(texto.lower())
    tokens_filtrados = [token for token in tokens if token not in stop_words]
    tokens_lemmatized = [lemmatizer.lemmatize(token) for token in tokens_filtrados]
    datos_procesados.append(' '.join(tokens_lemmatized))

# Crea una nueva columna para los datos preprocesados
df['Columna_de_datos_procesados'] = datos_procesados

# Representación del texto con TF-IDF
stop_words = set(stopwords.words('english'))
vectorizer = TfidfVectorizer(stop_words=stop_words)
X = vectorizer.fit_transform(datos_procesados)

# Verifica la forma de la matriz de características
print(X.shape)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Fankrit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# (47820, 37217)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Separa los datos en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, etiquetas, test_size=0.2, random_state=42)

# Entrena un modelo de clasificación supervisado usando Naive Bayes
clf = MultinomialNB()
clf.fit(X_train, y_train)

# Realiza predicciones en el conjunto de prueba y calcula la precisión
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo: {:.2f}%".format(accuracy * 100))
# Out:
# Precisión del modelo: 17.85%

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from tqdm import tqdm

# Separa los datos en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, etiquetas, test_size=0.2, random_state=42)

# Entrena un modelo de clasificación supervisado usando Regresión Logística
clf = LogisticRegression(random_state=42, max_iter=1000)

# Realiza el entrenamiento con una barra de progreso
for i in tqdm(range(10)):
    clf.fit(X_train, y_train)

# Realiza predicciones en el conjunto de prueba y calcula la precisión
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo: {:.2f}%".format(accuracy * 100))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
